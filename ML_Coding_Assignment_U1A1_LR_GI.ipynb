# %% [markdown]
# **Machine Learning: Code Assignment U1A1**
#
# **Linear Regression**
#
# Author: Gowtham Iyer

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load dataset (Real Estate Valuation Dataset) and print X1 to X4 and y variables.

# %%
dataset = pd.read_csv('/content/Real estate valuation data set.csv')
X1 = dataset['X1 transaction date']
X2 = dataset['X2 house age']
X3 = dataset['X3 distance to the nearest MRT station']
X4 = dataset['X4 number of convenience stores']
y = dataset['Y house price of unit area']

# %% [markdown]
# # Find the total number of samples in the dataset

# %%
print("Total number of samples in the dataset: ", len(X1))
# Out:
# Total number of samples in the dataset:  414

# %% [markdown]
# # Convert all input variables and the output variable to 1-D arrays from dataframes

# %%
print(X1.shape)
print(X2.shape)
print(X3.shape)
print(X4.shape)
print(y.shape)

X1 = np.reshape(X1.to_numpy(), (-1, 1))
X2 = np.reshape(X2.to_numpy(), (-1, 1))
X3 = np.reshape(X3.to_numpy(), (-1, 1))
X4 = np.reshape(X4.to_numpy(), (-1, 1))
y = np.reshape(y.to_numpy(), (-1, 1))

print(X1.shape)
print(X2.shape)
print(X3.shape)
print(X4.shape)
print(y.shape)

# %% [markdown]
# ## Feature-wise Scatter Plots against the output variable

# %%
# X1 - Transaction date
plt.scatter(X1, y, color = 'red')
plt.title('Real estate dataset - Price of unit area Vs Transaction date')
plt.xlabel('Transaction date')
plt.ylabel('House Price of unit area')
plt.show()

# X2 - House age
plt.scatter(X2, y, color = 'cyan')
plt.title('Real estate dataset - Price of unit area Vs House Age')
plt.xlabel('House Age')
plt.ylabel('House Price of unit area')
plt.show()

# X3 - Distance to nearest MRT station
plt.scatter(X3, y, color = 'blue')
plt.title('Real estate dataset - Price of unit area Vs Distance to nearest MRT station')
plt.xlabel('Distance to nearest MRT station')
plt.ylabel('House Price of unit area')
plt.show()

# X4 - Number of convenience stores
plt.scatter(X4, y, color = 'green')
plt.title('Real estate dataset - Price of unit area Vs Number of convenience stores')
plt.xlabel('Number of convenience stores')
plt.ylabel('House Price of unit area')
plt.show()

# %% [markdown]
# ## Create a Linear Regression Model object

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()

# %% [markdown]
# # Reading all input variables (features) into X array and output variable in y array

# %%
X = pd.read_excel('/content/Real estate valuation data set.xlsx', usecols='B:G')
print("Total number of samples in the dataset: ", len(X))

y = pd.read_excel('/content/Real estate valuation data set.xlsx', usecols='H')

y = np.array(y).ravel()
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)
# Out:
# Total number of samples in the dataset:  414

# %%
# Fitting Simple Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
regressor_1 = LinearRegression()
regressor_1.fit(X, y)
# Out:
# LinearRegression()

# %%
# Visualising the trained model
plt.scatter(X, y, color = 'red')
plt.plot(X, regressor_1.predict(X), color = 'blue')
plt.title('Salary vs Experience (dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# But how do we test our model?

# %% [markdown]
# ## Train Test Split

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3,
                                                    random_state = 42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (20, 1)
# (10, 1)

# %%
# Visualising the train and test dataset results
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_test, y_test, color = 'blue')
plt.title('Salary vs Experience (dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Train using training split

# %%
regressor_2 = LinearRegression()
regressor_2.fit(X_train, y_train)

y_pred = regressor_2.predict(X_test)

# %%
# Visualising the train and test dataset results
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor_2.predict(X_train), color='cyan')
#plt.plot(X_test, y_pred, color='grey')
#plt.scatter(X_test, y_test, color = 'blue')
plt.title('Salary vs Experience (dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Plot y_test and y_pred

# %%
# Visualising the y_test and y_pred results
plt.scatter(X_test, y_test, color = 'blue') #true
plt.scatter(X_test, y_pred, color = 'green')
plt.plot(X_test, y_pred, color='grey')
plt.title('Salary vs Experience (dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Evaluate the performance of our model - MSE and MAE

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print('MAE', mean_absolute_error(y_test, y_pred))
#print('MAE', mean_absolute_error(y_test, y_pred))
print('MSE', mean_squared_error(y_test, y_pred))
# Out:
# MAE 4956.5232614449005
# MSE 35301898.887134895
